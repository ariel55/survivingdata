# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

# %% [markdown]
# # CARGA DE DATOS
# # Los ultimos 3 años

# %%
datos8_13=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2013-08-01-properties-sell.csv',low_memory=False)
datos9_13=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2013-09-01-properties-sell.csv',low_memory=False)
datos10_13=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2013-10-01-properties-sell.csv',low_memory=False)
datos11_13=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2013-11-01-properties-sell.csv',low_memory=False)
datos12_13=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2013-12-01-properties-sell.csv',low_memory=False)

# %%
datos1_14=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2014-01-01-properties-sell.csv',low_memory=False)
datos2_14=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2014-02-01-properties-sell.csv',low_memory=False)
datos3_14=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2014-03-01-properties-sell.csv',low_memory=False)
datos4_14=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2014-04-01-properties-sell.csv',low_memory=False)
datos5_14=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2014-05-01-properties-sell.csv',low_memory=False)
datos6_14=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2014-06-01-properties-sell.csv',low_memory=False)

# %%
#los datos tomamos desde el 7/14 a 1/15
datos7_14_a_1_15=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2015-01-01-properties-sell-six_months.csv',low_memory=False)

# %%
#los datos tomados desde el 1/15 a 7/15
datos1_15_a_7_15=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2015-07-01-properties-sell-six_months.csv')

# %%
#los datos tomados desde el 6_15 a 12/15
datos6_15_a_12_15=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2015-12-01-properties-sell-six_months.csv',low_memory=False)

# %%
datos1_16=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2016-01-01-properties-sell.csv',low_memory=False)
datos2_16=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2016-02-01-properties-sell.csv',low_memory=False)
datos3_16=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2016-03-01-properties-sell.csv',low_memory=False)
datos4_16=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2016-04-01-properties-sell.csv',low_memory=False)
datos5_16=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2016-05-01-properties-sell.csv',low_memory=False)
datos6_16=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2016-06-01-properties-sell.csv',low_memory=False)
datos7_16=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2016-07-01-properties-sell.csv',low_memory=False)
datos8_16=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2016-08-01-properties-sell.csv',low_memory=False)
datos9_16=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2016-09-01-properties-sell.csv',low_memory=False)
datos10_16=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2016-10-01-properties-sell.csv',low_memory=False)
datos11_16=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2016-11-01-properties-sell.csv',low_memory=False)
datos12_16=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2016-12-01-properties-sell.csv',low_memory=False)

# %%
#los datos tomados desde el 1/17 a 7/17
datos1_17_a_7_17=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2017-07-01-properties-sell-six_months.csv',low_memory=False)

# %%
datos8_17=pd.read_csv('/home/sherly/Escritorio/archivoCSV-Properati/properati-AR-2017-08-01-properties-sell.csv',low_memory=False)

# %% [markdown]
# # FILTRAMOS LOS DATOS POR CABA Y GRAN BUENOS AIRES

# %%
datos8_13_CABA_GBA=datos8_13.loc[datos8_13.place_with_parent_names.str.contains('Bs.As.','Capital Federal'),:]

# %%
datos9_13_CABA_GBA=datos9_13.loc[datos9_13.place_with_parent_names.str.contains('Bs.As.','Capital Federal'),:]

# %%
datos10_13_CABA_GBA=datos10_13.loc[datos10_13.place_with_parent_names.str.contains('Bs.As.','Capital Federal'),:]
datos11_13_CABA_GBA=datos11_13.loc[datos11_13.place_with_parent_names.str.contains('Bs.As.','Capital Federal'),:]
datos12_13_CABA_GBA=datos12_13.loc[datos12_13.place_with_parent_names.str.contains('Bs.As.','Capital Federal'),:]

# %%
datos1_14_CABA_GBA=datos1_14.loc[datos1_14.place_with_parent_names.str.contains('Bs.As.','Capital Federal'),:]
datos2_14_CABA_GBA=datos2_14.loc[datos2_14.place_with_parent_names.str.contains('Bs.As.','Capital Federal'),:]
datos3_14_CABA_GBA=datos3_14.loc[datos3_14.place_with_parent_names.str.contains('Bs.As.','Capital Federal'),:]
datos4_14_CABA_GBA=datos4_14.loc[datos4_14.place_with_parent_names.str.contains('Bs.As.','Capital Federal'),:]
datos5_14_CABA_GBA=datos5_14.loc[datos5_14.place_with_parent_names.str.contains('Bs.As.','Capital Federal'),:]
datos6_14_CABA_GBA=datos6_14.loc[datos6_14.place_with_parent_names.str.contains('Bs.As.','Capital Federal'),:]

# %%
#apartir de este archivo las estructura cambia al que conocemos hoy en dia 

datos7_14_a_1_15_CABA_GBA=datos7_14_a_1_15.loc[datos7_14_a_1_15.state_name.str.contains('Bs.As.','Capital Federal'),:]
datos1_15_a_7_15_CABA_GBA=datos1_15_a_7_15.loc[datos1_15_a_7_15.state_name.str.contains('Bs.As.','Capital Federal'),:]
datos6_15_a_12_15_CABA_GBA=datos6_15_a_12_15.loc[datos6_15_a_12_15.state_name.str.contains('Bs.As.','Capital Federal'),:]

# %%
datos1_16_CABA_GBA=datos1_16.loc[datos1_16.state_name.str.contains('Bs.As.','Capital Federal'),:]
datos2_16_CABA_GBA=datos2_16.loc[datos2_16.state_name.str.contains('Bs.As.','Capital Federal'),:]
datos3_16_CABA_GBA=datos3_16.loc[datos3_16.state_name.str.contains('Bs.As.','Capital Federal'),:]
datos4_16_CABA_GBA=datos4_16.loc[datos4_16.state_name.str.contains('Bs.As.','Capital Federal'),:]
datos5_16_CABA_GBA=datos5_16.loc[datos5_16.state_name.str.contains('Bs.As.','Capital Federal'),:]
datos6_16_CABA_GBA=datos6_16.loc[datos6_16.state_name.str.contains('Bs.As.','Capital Federal'),:]
datos7_16_CABA_GBA=datos7_16.loc[datos7_16.state_name.str.contains('Bs.As.','Capital Federal'),:]
datos8_16_CABA_GBA=datos8_16.loc[datos8_16.state_name.str.contains('Bs.As.','Capital Federal'),:]
datos9_16_CABA_GBA=datos9_16.loc[datos9_16.state_name.str.contains('Bs.As.','Capital Federal'),:]
datos10_16_CABA_GBA=datos10_16.loc[datos10_16.state_name.str.contains('Bs.As.','Capital Federal'),:]
datos11_16_CABA_GBA=datos11_16.loc[datos11_16.state_name.str.contains('Bs.As.','Capital Federal'),:]
datos12_16_CABA_GBA=datos12_16.loc[datos12_16.state_name.str.contains('Bs.As.','Capital Federal'),:]

# %%
datos1_17_a_7_17_CABA_GBA=datos1_17_a_7_17.loc[datos1_17_a_7_17.state_name.str.contains('Bs.As.','Capital Federal'),:]
datos8_17_CABA_GBA=datos8_17.loc[datos8_17.state_name.str.contains('Bs.As.','Capital Federal'),:]

# %% [markdown]
# # ELIMINAMOS COLUMNAS QUE NO APORTAN AL ESTUDIO
#
# # operation, place_with_parent_names, country_name, state_name, geonames_id, lat-lon, price, currency, price_aprox_local_currency, price_per_m2, properati_url, title, image_thumbnail

# %%
#datos8_13_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url, title", "image_thumbnail"])
datos8_13_CABA_GBA.drop(["operation", "place_with_parent_names", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "properati_url", "image_thumbnail"],axis=1,inplace=True)
datos9_13_CABA_GBA.drop(["operation", "place_with_parent_names", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "properati_url", "image_thumbnail"],axis=1,inplace=True)
datos10_13_CABA_GBA.drop(["operation", "place_with_parent_names", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "properati_url", "image_thumbnail"],axis=1,inplace=True)
datos11_13_CABA_GBA.drop(["operation", "place_with_parent_names", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "properati_url", "image_thumbnail"],axis=1,inplace=True)
datos12_13_CABA_GBA.drop(["operation", "place_with_parent_names", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "properati_url", "image_thumbnail"],axis=1,inplace=True)
# Out:
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
datos1_14_CABA_GBA.drop(["operation", "place_with_parent_names", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "properati_url", "image_thumbnail"],axis=1,inplace=True)
datos2_14_CABA_GBA.drop(["operation", "place_with_parent_names", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "properati_url", "image_thumbnail"],axis=1,inplace=True)
datos3_14_CABA_GBA.drop(["operation", "place_with_parent_names", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "properati_url", "image_thumbnail"],axis=1,inplace=True)
datos4_14_CABA_GBA.drop(["operation", "place_with_parent_names", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "properati_url", "image_thumbnail"],axis=1,inplace=True)
datos5_14_CABA_GBA.drop(["operation", "place_with_parent_names", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "properati_url", "image_thumbnail"],axis=1,inplace=True)
datos6_14_CABA_GBA.drop(["operation", "place_with_parent_names", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "properati_url", "image_thumbnail"],axis=1,inplace=True)
# Out:
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
#datos8_13_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url, title", "image_thumbnail"])
datos7_14_a_1_15_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url", "title", "image_thumbnail"],axis=1,inplace=True)
datos1_15_a_7_15_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url", "title", "image_thumbnail"],axis=1,inplace=True)
datos6_15_a_12_15_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url", "title", "image_thumbnail"],axis=1,inplace=True)
# Out:
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
datos1_16_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url", "title", "image_thumbnail"],axis=1,inplace=True)
datos2_16_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url", "title", "image_thumbnail"],axis=1,inplace=True)
datos3_16_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url", "title", "image_thumbnail"],axis=1,inplace=True)
datos4_16_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url", "title", "image_thumbnail"],axis=1,inplace=True)
datos5_16_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url", "title", "image_thumbnail"],axis=1,inplace=True)
datos6_16_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url", "title", "image_thumbnail"],axis=1,inplace=True)
datos7_16_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url", "title", "image_thumbnail"],axis=1,inplace=True)
datos8_16_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url", "title", "image_thumbnail"],axis=1,inplace=True)
datos9_16_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url", "title", "image_thumbnail"],axis=1,inplace=True)
datos10_16_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url", "title", "image_thumbnail"],axis=1,inplace=True)
datos11_16_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url", "title", "image_thumbnail"],axis=1,inplace=True)
datos12_16_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url", "title", "image_thumbnail"],axis=1,inplace=True)
# Out:
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
datos1_17_a_7_17_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url", "title", "image_thumbnail"],axis=1,inplace=True)
datos8_17_CABA_GBA.drop(["operation", "place_with_parent_names", "country_name", "state_name", "geonames_id", "lat-lon", "price", "currency", "price_aprox_local_currency", "price_per_m2", "properati_url", "title", "image_thumbnail"],axis=1,inplace=True)
# Out:
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# # FILTRAMOS POR PRECIOS NAN'S YA QUE CONSIDERAMOS QUE NO APORTAN AL ESTUDIO DE DATOS:

# %%
datos8_13_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_in_m2'],inplace=True)
datos9_13_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_in_m2'],inplace=True)
datos10_13_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_in_m2'],inplace=True)
datos10_13_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_in_m2'],inplace=True)
datos11_13_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_in_m2'],inplace=True)
datos12_13_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_in_m2'],inplace=True)
datos1_14_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_in_m2'],inplace=True)
datos2_14_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_in_m2'],inplace=True)
datos3_14_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_in_m2'],inplace=True)
datos4_14_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_in_m2'],inplace=True)
datos5_14_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_in_m2'],inplace=True)
datos6_14_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_in_m2'],inplace=True)
datos7_14_a_1_15_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_total_in_m2'],inplace=True)
datos1_15_a_7_15_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_total_in_m2'],inplace=True)
datos6_15_a_12_15_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_total_in_m2'],inplace=True)
# Out:
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
datos1_16_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_total_in_m2'],inplace=True)
datos2_16_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_total_in_m2'],inplace=True)
datos3_16_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_total_in_m2'],inplace=True)
datos4_16_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_total_in_m2'],inplace=True)
datos5_16_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_total_in_m2'],inplace=True)
datos6_16_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_total_in_m2'],inplace=True)
datos7_16_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_total_in_m2'],inplace=True)
datos8_16_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_total_in_m2'],inplace=True)
datos9_16_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_total_in_m2'],inplace=True)
datos10_16_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_total_in_m2'],inplace=True)
datos11_16_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_total_in_m2'],inplace=True)
datos12_16_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_total_in_m2'],inplace=True)
datos1_17_a_7_17_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_total_in_m2'],inplace=True)
datos8_17_CABA_GBA.dropna(subset=['price_usd_per_m2','surface_total_in_m2'],inplace=True)
# Out:
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sherly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
# sacamos los datos de 2013, hacemos un merge pára no tener datos repetidos
publicaciones2013=pd.merge(datos8_13_CABA_GBA,datos9_13_CABA_GBA,how='outer',on=["created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses"])
publicaciones2013=pd.merge(datos10_13_CABA_GBA,publicaciones2013,how='outer',on=["created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses"])
publicaciones2013=pd.merge(datos11_13_CABA_GBA,publicaciones2013,how='outer',on=["created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses"])
publicaciones2013=pd.merge(datos12_13_CABA_GBA,publicaciones2013,how='outer',on=["created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses"])
publicaciones2013
# Out:
#         created_on property_type            place_name        lat        lon  \
# 0       2012-08-08         house       Villa Ballester        NaN        NaN
# 1       2012-08-08         house            San Martín -34.542278 -58.505344
# 2       2012-08-08     apartment                 Tigre        NaN        NaN
# 3       2012-08-08         house                 Pilar -34.452498 -58.931356
# 4       2012-08-08         house                 Tigre -34.451013 -58.626786
# 5       2012-08-18     apartment                 Tigre        NaN        NaN
# 6       2012-09-12         house                 Tigre        NaN        NaN
# 7       2012-09-19         house                 Tigre        NaN        NaN
# 8       2012-09-19         house                 Tigre        NaN        NaN
# 9       2012-09-19         house         Villa Udaondo        NaN        NaN
# 10      2012-09-19         house  San Antonio De Padua -34.676801 -58.693682
# ...

# %%
# renombramos la columna surface_in_m2 por surface_total_in_m2
# renombramos la columna en publicaciones2013
publicaciones2013.rename(columns={'surface_in_m2':'surface_total_in_m2'},inplace=True)

# %%
publicaciones2014=pd.merge(datos1_14_CABA_GBA,datos2_14_CABA_GBA,how='outer',on=["created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses"])
publicaciones2014=pd.merge(datos3_14_CABA_GBA,publicaciones2014,how='outer',on=["created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses"])
publicaciones2014=pd.merge(datos4_14_CABA_GBA,publicaciones2014,how='outer',on=["created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses"])
publicaciones2014=pd.merge(datos5_14_CABA_GBA,publicaciones2014,how='outer',on=["created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses"])
publicaciones2014=pd.merge(datos6_14_CABA_GBA,publicaciones2014,how='outer',on=["created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses"])
#renombramos la columna
publicaciones2014.rename(columns={'surface_in_m2':'surface_total_in_m2'},inplace=True)

publicaciones2014=pd.merge(publicaciones2014,datos7_14_a_1_15_CABA_GBA,how='outer',on=["created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_total_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses"])
publicaciones2014
# Out:
#         created_on property_type                           place_name  \
# 0       2012-08-08         house                      Villa Ballester
# 1       2012-08-08         house       Villa Granaderos De San Martin
# 2       2012-08-08         house                                Pilar
# 3       2012-09-12         house                                Tigre
# 4       2012-09-19         house                                Tigre
# 5       2012-09-19         house                 San Antonio De Padua
# 6       2012-09-28     apartment                          Ramos Mejía
# 7       2012-09-28     apartment                          Ramos Mejía
# 8       2012-09-28     apartment                          Ramos Mejía
# 9       2012-09-28     apartment                          Ramos Mejía
# 10      2012-09-28     apartment                          Ramos Mejía
# 11      2012-09-28     apartment                          Ramos Mejía
# ...

# %%
publicaciones2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 217955 entries, 0 to 217954
# Data columns (total 14 columns):
# created_on               217955 non-null object
# property_type            217955 non-null object
# place_name               217953 non-null object
# lat                      207197 non-null float64
# lon                      207197 non-null float64
# price_aprox_usd          217949 non-null float64
# surface_total_in_m2      217955 non-null float64
# price_usd_per_m2         217955 non-null float64
# floor                    16513 non-null float64
# rooms                    189642 non-null float64
# expenses                 914 non-null object
# id                       3679 non-null object
# surface_covered_in_m2    3397 non-null float64
# description              3679 non-null object
# dtypes: float64(8), object(6)
# memory usage: 24.9+ MB

# %%
publicaciones2015=pd.merge(datos1_15_a_7_15_CABA_GBA,datos6_15_a_12_15_CABA_GBA,how='outer',on=["id","created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_total_in_m2","surface_covered_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses","description"])
publicaciones2015
# Out:
#                                              id  created_on property_type  \
# 0      7db7ff40919fafc956537d1496c04d7d8b7a322f  2015-01-02         house
# 1      280d1aa5574dfc6e161728887e5c7f203040c709  2015-01-02         house
# 2      0e8c14c73fa13d0ac2bf6b83f111019d7f9096e7  2015-01-03         house
# 3      fae36d7495359309753b0912070baa0045dd3b36  2015-01-05         house
# 4      08b87a88d10e4326b28c33e9af6e9aed5920436e  2015-01-05         house
# 5      5730340bddfd9b800784a76718c671182cc8eb7a  2015-01-05         house
# 6      44a9c4e929000fa2ee84b5b8ee92f6bbb285eb62  2015-01-05         house
# 7      d16667cc7c7c4277420999ba9e112883c98477df  2015-01-07     apartment
# 8      dcbcdb5997a2d4bc6331fd6f3cbcb23364f2c53d  2015-01-08         house
# 9      bcd452f61e075445eee82a5682d7619d8dc1f783  2015-01-08     apartment
# 10     14315554572f50939a8e9af4c2c78029df2cb51e  2015-01-08     apartment
# 11     35e2612f305fc12461e9313180c7031589695b76  2015-01-08         house
# ...

# %%
publicaciones2016=pd.merge(datos1_16_CABA_GBA,datos2_16_CABA_GBA,how='outer',on=["id","created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_total_in_m2","surface_covered_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses","description"])
publicaciones2016=pd.merge(datos3_16_CABA_GBA,publicaciones2016,how='outer',on=["id","created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_total_in_m2","surface_covered_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses","description"])
publicaciones2016=pd.merge(datos4_16_CABA_GBA,publicaciones2016,how='outer',on=["id","created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_total_in_m2","surface_covered_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses","description"])
publicaciones2016=pd.merge(datos5_16_CABA_GBA,publicaciones2016,how='outer',on=["id","created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_total_in_m2","surface_covered_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses","description"])
publicaciones2016=pd.merge(datos6_16_CABA_GBA,publicaciones2016,how='outer',on=["id","created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_total_in_m2","surface_covered_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses","description"])
publicaciones2016=pd.merge(datos7_16_CABA_GBA,publicaciones2016,how='outer',on=["id","created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_total_in_m2","surface_covered_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses","description"])
publicaciones2016=pd.merge(datos8_16_CABA_GBA,publicaciones2016,how='outer',on=["id","created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_total_in_m2","surface_covered_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses","description"])
publicaciones2016=pd.merge(datos9_16_CABA_GBA,publicaciones2016,how='outer',on=["id","created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_total_in_m2","surface_covered_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses","description"])
publicaciones2016=pd.merge(datos10_16_CABA_GBA,publicaciones2016,how='outer',on=["id","created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_total_in_m2","surface_covered_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses","description"])
publicaciones2016=pd.merge(datos11_16_CABA_GBA,publicaciones2016,how='outer',on=["id","created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_total_in_m2","surface_covered_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses","description"])
publicaciones2016=pd.merge(datos12_16_CABA_GBA,publicaciones2016,how='outer',on=["id","created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_total_in_m2","surface_covered_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses","description"])
publicaciones2016
# Out:
#                                              id  created_on property_type  \
# 0      a786b4d9a8f6cc86ba3e839f4cb85bbb03cf15fd  2016-06-01         house
# 1      9844244d17eb024e0632a63b4098b67889de06bc  2016-06-01         house
# 2      0bf7e57e034c3742f303d74256c2448d19b577bb  2016-06-01         house
# 3      d39b18e6f6d07d1c87c96d36d7c33a075194ac06  2016-06-01         house
# 4      d65b8fd3b9a990ad94c9f5e35d8f05bae7d6d495  2016-06-01         house
# 5      e19ee58ed330ab9a3104cb5609aff7b26c9fa425  2016-06-01         house
# 6      258df0215a86642f380a1d4299f65ba7a287e944  2016-06-01         house
# 7      dc1abbff558dbf36f5bd0b7f49070c8c043edcb2  2016-06-01         house
# 8      c23920a481f6820f65e17a6efe26566ddcde8888  2016-06-01         house
# 9      9d46d3a6d09396f4656d6c0d1a2f873b3ea3856d  2016-06-01     apartment
# 10     d1d7dc2fbb20710325bee1d5022171b2b0da61c2  2016-06-01         house
# 11     2a500d137328cbd6206e3251674c501abe1c0242  2016-06-01         house
# ...

# %%
publicaciones2017=pd.merge(datos1_17_a_7_17_CABA_GBA,datos8_17_CABA_GBA,how='outer',on=["id","created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_total_in_m2","surface_covered_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses","description"])
publicaciones2017
# Out:
#                                              id  created_on property_type  \
# 0      80caba5f926d8cd0a0546aab898b76e4ab59a8ad  2017-01-02            PH
# 1      32add0bb9531c5a8e9879fcfa74dce5023c3a21a  2017-01-02         house
# 2      82ead77de71d5f1b28766b3a64f1ffbe1fcd4a24  2017-01-02         store
# 3      2764eb2c6321ff00621fb37b587d184ccb569df1  2017-01-02     apartment
# 4      483d013e58c100bef43b383628e958f99a128d9d  2017-01-02         store
# 5      fbbf30cf803d04467ec74b1ad4df5873c8c60def  2017-01-02         house
# 6      4c442f25ae6d2b36cde536f41b2af7411528d762  2017-01-02         house
# 7      64a101334092138eb63c3cdabfbe6a561bddaadb  2017-01-02     apartment
# 8      383e857a40cff55fe97df365909be329551f04f1  2017-01-02     apartment
# 9      b6e5fd84d47ec7ea059bd14079b5d2fedf3ed91c  2017-01-02     apartment
# 10     3086e594253f7d98d5c808eb69c18cdd1979a6e6  2017-01-02     apartment
# 11     4ba4a64539799b8203b5e8b7eca14f6694b5ce91  2017-01-02     apartment
# ...

# %%
publicacion_Total=pd.merge(publicaciones2015,publicaciones2016,how='outer',on=["id","created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_total_in_m2","surface_covered_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses","description"])

# %%
publicacion_Total=pd.merge(publicacion_Total,publicaciones2017,how='outer',on=["id","created_on","property_type",
                                                                                "place_name","lat","lon",
                                                                                "price_aprox_usd","surface_total_in_m2","surface_covered_in_m2","price_usd_per_m2",
                                                                                "floor","rooms","expenses","description"])
publicacion_Total
# Out:
#                                              id  created_on property_type  \
# 0      7db7ff40919fafc956537d1496c04d7d8b7a322f  2015-01-02         house
# 1      280d1aa5574dfc6e161728887e5c7f203040c709  2015-01-02         house
# 2      0e8c14c73fa13d0ac2bf6b83f111019d7f9096e7  2015-01-03         house
# 3      fae36d7495359309753b0912070baa0045dd3b36  2015-01-05         house
# 4      08b87a88d10e4326b28c33e9af6e9aed5920436e  2015-01-05         house
# 5      5730340bddfd9b800784a76718c671182cc8eb7a  2015-01-05         house
# 6      44a9c4e929000fa2ee84b5b8ee92f6bbb285eb62  2015-01-05         house
# 7      d16667cc7c7c4277420999ba9e112883c98477df  2015-01-07     apartment
# 8      dcbcdb5997a2d4bc6331fd6f3cbcb23364f2c53d  2015-01-08         house
# 9      bcd452f61e075445eee82a5682d7619d8dc1f783  2015-01-08     apartment
# 10     14315554572f50939a8e9af4c2c78029df2cb51e  2015-01-08     apartment
# 11     35e2612f305fc12461e9313180c7031589695b76  2015-01-08         house
# ...

# %%
publicacion_Total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93407 entries, 0 to 93406
# Data columns (total 14 columns):
# id                       93407 non-null object
# created_on               93407 non-null object
# property_type            93407 non-null object
# place_name               93366 non-null object
# lat                      54508 non-null float64
# lon                      54508 non-null float64
# price_aprox_usd          93407 non-null float64
# surface_total_in_m2      93407 non-null float64
# surface_covered_in_m2    89054 non-null float64
# price_usd_per_m2         93407 non-null float64
# floor                    9883 non-null float64
# rooms                    35426 non-null float64
# expenses                 9119 non-null float64
# description              93405 non-null object
# dtypes: float64(9), object(5)
# memory usage: 10.7+ MB

# %%
publicacionId=publicacion_Total['id']
publicacionId.value_counts()
# Out:
# 313dccc2f3db5d7c4a8fd2d74c7b39057e4bf439    4
# 48bbabe7e0d2ded1a980f92cf172693747d54d0f    4
# 76a7e6257092a380c270c28104df5584a36fd5bf    4
# 649df6ca2284a69c1306a21ee39b399aac8704e6    4
# 9c09a34b6d7670aadff7566dde51d3937063c7f3    4
# 46120780047e51bf8d84799e9c6306fdb531fd91    4
# 688b16e3bed2f3f917818b541a9ebda4c8146658    4
# 68cbfe02c98a34b35461349c3a93528b3fb23ed0    4
# e5320ad2eba49dff1c081477147b79e5369bb119    4
# 60e38174ec9916d4f571a4440f20d04acbc2653e    4
# c8f266f2a68f6bb1b8d4bffcb8c772cb8140475e    4
# b8aca30a850f62538cf13d26c00622f79ca581b0    4
# 630062754fbb790c0a8e3b4feb01aa3eee4960c0    4
# 337367806c3e729eb22089e1204285d31d7c07a4    4
# 4eb64eaf32cb348e2908effab6c4cea0e34ccee5    4
# 3db08e7c78767b21fb6dffa80b26f679645d705d    3
# 63cb40f3c465489a85f4148242496871289c35bb    3
# 89a92c74f1fb755df671cac9242da203db0543bf    3
# 2cbc567a81d10807982e4115bed6c3900c85f7b3    3
# a9ed485bb1f68b229aebd3b07e5f3a219f178afd    3
# ...

# %%
publicacion_Total[(publicacion_Total['id']== '313dccc2f3db5d7c4a8fd2d74c7b39057e4bf439')]
# Out:
#                                              id  created_on property_type  \
# 17716  313dccc2f3db5d7c4a8fd2d74c7b39057e4bf439  2015-12-21         house
# 47537  313dccc2f3db5d7c4a8fd2d74c7b39057e4bf439  2015-12-21         house
# 49590  313dccc2f3db5d7c4a8fd2d74c7b39057e4bf439  2015-12-21         house
# 71971  313dccc2f3db5d7c4a8fd2d74c7b39057e4bf439  2015-12-21         house
#
#       place_name        lat        lon  price_aprox_usd  surface_total_in_m2  \
# 17716       Glew -34.878542 -58.351788         24313.29                260.0
# 47537       Glew -34.878542 -58.351788         26301.78                260.0
# 49590       Glew -34.878542 -58.351788         26473.36                260.0
# 71971       Glew -34.878542 -58.351788         23555.14                260.0
#
#        surface_covered_in_m2  price_usd_per_m2  floor  rooms  expenses  \
# 17716                   72.0         93.512654    NaN    NaN       NaN
# ...
